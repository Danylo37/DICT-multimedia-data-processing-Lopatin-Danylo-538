# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Завдання
# 1. Створити сигнал, який є сумою синусоїд 50 Гц та 120 Гц.
# 2. Створити адитивну суміш сигналу та шуму АБГШ (СКВ 2,5).
# 3. Застосувати перетворення Фур'є (np.fft.fft()).
# 4. Отримати та побудувати спектральну щільність потужності  ($PSD = y* \hat{y} / n$),  y- результат застосування перетворення Фур'є, $\hat{y}$ - вказує на комплексно-сполучену величину, n - кількість відліків (використати np.conj).
# 5. Занулити коефіцієнти, які нижчі за поріг (установити поріг 100).
# 6. Застосувати зворотне перетворення Фур'є.
# 7. Вивести отриманий результат.

# %%
#dt = 0.001
#t = np.arange(0, 1, dt)

# %%
#plt.plot(t, x_n,  color='c', linewidth=1.5, label = 'Noisy signal')
#plt.plot(t, x,  color='k', linewidth=2.0, label = 'Input signal')
#plt.xlim(t[0], t[-1])
#plt.legend()

# %%
#plt.plot(t, f_inp,  color='k', linewidth=2.0, label = 'Input signal')
#plt.xlim(t[0], t[-1])
#plt.legend()
#plt.show()
